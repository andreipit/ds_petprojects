# %%
import pandas as pd
import re

def save2txt(row):
    if row[0]<10: row[0] = "0" + str(row[0])
    file_name = str(row[0]).strip() + "_" + row[1].strip() + "_" + row[2].strip()
    print(file_name)
    file = open(file_name+'.py', 'w')
    line = "0) summary-------------------------------------------------------------------------------"
    file.write(file_name+'.py' + '\n' + '\n' + line)
    file.close()
    return row

df = pd.read_csv('calendar.txt', skiprows=0, delimiter="\t")

df['TOPICS'] = df['TOPICS'].str.replace(' ', '_')
df['TOPICS'] = df['TOPICS'].str.replace('\\', 'ibackslash')
df['TOPICS'] = df['TOPICS'].str.replace('/', 'islash')
df['TOPICS'] = df['TOPICS'].str.replace(':', 'icolon')
df['TOPICS'] = df['TOPICS'].str.replace('*', 'istar')
df['TOPICS'] = df['TOPICS'].str.replace('?', 'iquest')
df['TOPICS'] = df['TOPICS'].str.replace('"', 'iquotes')
df['TOPICS'] = df['TOPICS'].str.replace('<', 'iless')
df['TOPICS'] = df['TOPICS'].str.replace('>', 'imore')
df['TOPICS'] = df['TOPICS'].str.replace('|', 'ior')

df['KEY DATES'] = df['KEY DATES'].str.replace(' ', '_')
df['KEY DATES'] = df['KEY DATES'].str.replace('\\', 'ibackslash')
df['KEY DATES'] = df['KEY DATES'].str.replace('/', 'islash')
df['KEY DATES'] = df['KEY DATES'].str.replace(':', 'icolon')
df['KEY DATES'] = df['KEY DATES'].str.replace('*', 'istar')
df['KEY DATES'] = df['KEY DATES'].str.replace('?', 'iquest')
df['KEY DATES'] = df['KEY DATES'].str.replace('"', 'iquotes')
df['KEY DATES'] = df['KEY DATES'].str.replace('<', 'iless')
df['KEY DATES'] = df['KEY DATES'].str.replace('>', 'imore')
df['KEY DATES'] = df['KEY DATES'].str.replace('|', 'ior')

df.apply(save2txt, axis=1)
# Out:
# 01_The_geometry_of_linear_iquotes_equations__
# 01_The_geometry_of_linear_iquotes_equations__
# 02_Elimination_with_matrices__
# 03_Matrix_operations_and_inverses__
# 04_LU_and_LDU_factorization__
# 05_Transposes_and_permutations_Problem_set_1_due
# 06_Vector_spaces_and_subspaces__
# 07_The_nullspaceicolon_Solving_Ax_=_0__
# 08_Rectangular_PA_=_LU_and_Ax_=_b_Problem_set_2_due
# 09_Row_reduced_echelon_form__
# 10_Basis_and_dimension__
# 11_The_four_fundamental_subspaces_Problem_set_3_due
# 12_Exam_1icolon_Chapters_1_to_3.4__
# 13_Graphs_and_networks__
# 14_Orthogonality_Problem_set_4_due
# 15_Projections_and_subspaces__
# 16_Least_squares_approximations__
# 17_Gram-Schmidt_and_A_=_QR_Problem_set_5_due
# 18_Properties_of_determinants__
# 19_Formulas_for_determinants__
# 20_Applications_of_determinants_Problem_set_6_due
# 21_Eigenvalues_and_eigenvectors__
# 22_Diagonalization__
# 23_Markov_matrices_Problem_set_7_due
# 24_Review_for_exam_2__
# 25_Exam_2icolon_Chapters_1-5,_6.1-6.2,_8.2__
# 26_Differential_equations__
# 27_Symmetric_matrices__
# 28_Positive_definite_matrices__
# 29_Matrices_in_engineering_Problem_set_8_due
# 30_Similar_matrices__
# 31_Singular_value_decomposition_Problem_set_9_due
# 32_Fourier_series,_FFT,_complex_matrices__
# 33_Linear_transformations__
# 34_Choice_of_basis_Problem_set_10_due
# 35_Linear_programming__
# 36_Course_review__
# 37_Exam_3icolon_Chapters_1-8_(8.1,_2,_3,_5)__
# 38_Numerical_linear_algebra__
# 39_Computational_science__
# 40_Final_exam__
#    SES #                                    TOPICS           KEY DATES
# 0     01  The_geometry_of_linear_iquotes_equations                   _
# 1     02                 Elimination_with_matrices                   _
# 2     03            Matrix_operations_and_inverses                   _
# 3     04                  LU_and_LDU_factorization                   _
# 4     05               Transposes_and_permutations   Problem_set_1_due
# 5     06               Vector_spaces_and_subspaces                   _
# 6     07        The_nullspaceicolon_Solving_Ax_=_0                   _
# 7     08            Rectangular_PA_=_LU_and_Ax_=_b   Problem_set_2_due
# 8     09                  Row_reduced_echelon_form                   _
# 9     10                       Basis_and_dimension                   _
# 10    11            The_four_fundamental_subspaces   Problem_set_3_due
# 11    12            Exam_1icolon_Chapters_1_to_3.4                   _
# 12    13                       Graphs_and_networks                   _
# 13    14                             Orthogonality   Problem_set_4_due
# 14    15                 Projections_and_subspaces                   _
# 15    16              Least_squares_approximations                   _
# 16    17                   Gram-Schmidt_and_A_=_QR   Problem_set_5_due
# 17    18                Properties_of_determinants                   _
# 18    19                 Formulas_for_determinants                   _
# 19    20              Applications_of_determinants   Problem_set_6_due
# 20    21              Eigenvalues_and_eigenvectors                   _
# 21    22                           Diagonalization                   _
# 22    23                           Markov_matrices   Problem_set_7_due
# 23    24                         Review_for_exam_2                   _
# 24    25   Exam_2icolon_Chapters_1-5,_6.1-6.2,_8.2                   _
# 25    26                    Differential_equations                   _
# 26    27                        Symmetric_matrices                   _
# 27    28                Positive_definite_matrices                   _
# 28    29                   Matrices_in_engineering   Problem_set_8_due
# 29    30                          Similar_matrices                   _
# 30    31              Singular_value_decomposition   Problem_set_9_due
# 31    32     Fourier_series,_FFT,_complex_matrices                   _
# 32    33                    Linear_transformations                   _
# 33    34                           Choice_of_basis  Problem_set_10_due
# 34    35                        Linear_programming                   _
# 35    36                             Course_review                   _
# 36    37  Exam_3icolon_Chapters_1-8_(8.1,_2,_3,_5)                   _
# 37    38                  Numerical_linear_algebra                   _
# 38    39                     Computational_science                   _
# 39    40                                Final_exam                   _
